# %%
import pandas
import os 
os.listdir("/Users/lianxing/Desktop/目前学习/python_project/Jupyter/supermarkets/")
BASE_DIR = "/Users/lianxing/Desktop/目前学习/python_project/Jupyter/supermarkets/"

# %%
df_csv = pandas.read_csv(BASE_DIR+"supermarkets.csv")
df_csv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_json = pandas.read_json(BASE_DIR+"supermarkets.json")
df_json
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_excel = pandas.read_excel(BASE_DIR+'supermarkets.xlsx',sheet_name=0)
df_excel
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df_txt = pandas.read_csv(BASE_DIR+"supermarkets-commas.txt")
df_txt
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
data = pandas.read_csv(BASE_DIR+"data.txt",sep=";",header=None)
data
# Out:
#    0                1              2                 3    4             5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA       Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA   Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA   Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA    Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA       Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA    Richvalley  20

# %%
data.columns = ['ID','Address','City','ZIP','Country','Name','Employees']
data
# Out:
#    ID          Address           City               ZIP Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
data.set_index("ID") #Not inplace
# Out:
#             Address           City               ZIP Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
data.columns[:]
# Out:
# Index(['ID', 'Address', 'City', 'ZIP', 'Country', 'Name', 'Employees'], dtype='object')

# %%
data_0 = data.set_index("ID")

# %%
data.set_index("ID",inplace=True)

# %%
data
# Out:
#    ID          Address           City               ZIP Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
data
# Out:
#             Address           City               ZIP Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
data["Address"]
# Out:
# ID
# 1       3666 21st St
# 2     735 Dolores St
# 3        332 Hill St
# 4       3995 23rd St
# 5    1056 Sanchez St
# 6    551 Alvarado St
# Name: Address, dtype: object

# %%
data.set_index("City")
# Out:
#                        Address               ZIP Country          Name  \
# City
# San Francisco     3666 21st St          CA 94114     USA       Madeira
# San Francisco   735 Dolores St          CA 94119     USA   Bready Shop
# San Francisco      332 Hill St  California 94114     USA   Super River
# San Francisco     3995 23rd St          CA 94114     USA    Ben's Shop
# San Francisco  1056 Sanchez St        California     USA       Sanchez
# San Francisco  551 Alvarado St          CA 94114     USA    Richvalley
#
#                Employees
# City
# San Francisco          8
# San Francisco         15
# San Francisco         25
# San Francisco         10
# San Francisco         12
# San Francisco         20

# %%
data['']
